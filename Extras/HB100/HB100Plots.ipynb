# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import stft

# %% [markdown]
# ### The following notebook details an investigation into the effects of adding a DC shift to the HB100 radar. All data was sampled at 40ksps.

# %% [markdown]
# # Raw HB100 Output

# %%
# Initialize empty lists to store time and voltage data
time_data = []
voltage_data = []

# Read data from the text file
with open('AddingaDCShifttoTheRadar/RawRadarOutputBeforeDCShift.txt', 'r') as file:
    next(file)  # Skip the header line
    next(file)
    for line in file:
        # Split each line into columns using whitespace as the delimiter
        columns = line.strip().split()
        if len(columns) == 2:
            time_data.append(float(columns[0]))
            voltage_data.append(float(columns[1]))

voltage_data = np.array(voltage_data) #converting voltage_data into a numpy array


# Create the plot
plt.figure(figsize=(10, 6))  # Optional: Set the figure size
plt.plot(time_data, voltage_data, color='b')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title('HB100 Raw Data Sampled at 40ksps')
plt.grid(True)


# Show the plot
plt.show()

# %% [markdown]
# # HB100 Sampled after DC Shift using 47uF Capacitor

# %%
# Initialize empty lists to store time and voltage data
time_data = []
voltage_data = []

# Read data from the text file
with open('AddingaDCShiftToTheRadar/RawRadarOutputAfterDCShift47uF.txt', 'r') as file:
    next(file)  # Skip the header line
    next(file)
    for line in file:
        # Split each line into columns using whitespace as the delimiter
        columns = line.strip().split()
        if len(columns) == 2:
            time_data.append(float(columns[0]))
            voltage_data.append(float(columns[1]))

voltage_data = np.array(voltage_data) #converting voltage_data into a numpy array


# Create the plot
plt.figure(figsize=(10, 6))  # Optional: Set the figure size
plt.plot(time_data, voltage_data, color='b')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title('Adding a DC Shift Using 47uF Capacitor')
plt.grid(True)


# Show the plot
plt.show()

# %% [markdown]
# # Adding a DC Shift Using 10uF Capacitor

# %%
# Initialize empty lists to store time and voltage data
time_data = []
voltage_data = []

# Read data from the text file
with open('AddingaDCShiftToTheRadar/AddingaDCShiftUsing10uF.txt', 'r') as file:
    next(file)  # Skip the header line
    next(file)
    for line in file:
        # Split each line into columns using whitespace as the delimiter
        columns = line.strip().split()
        if len(columns) == 2:
            time_data.append(float(columns[0]))
            voltage_data.append(float(columns[1]))

voltage_data = np.array(voltage_data) #converting voltage_data into a numpy array


# Create the plot
plt.figure(figsize=(10, 6))  # Optional: Set the figure size
plt.plot(time_data, voltage_data, color='b')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title('Adding a DC Shift Using 10uF Capacitor')
plt.grid(True)


# Show the plot
plt.show()

# %% [markdown]
# # HB100 DC Shifted Using 10uF And the Amplified Using JYVA2

# %%
# Initialize empty lists to store time and voltage data
time_data = []
voltage_data = []

# Read data from the text file
with open('AddingaDCShiftToTheRadar/HB100DCShiftUsing10uFWithJYVA2.txt', 'r') as file:
    next(file)  # Skip the header line
    next(file)
    for line in file:
        # Split each line into columns using whitespace as the delimiter
        columns = line.strip().split()
        if len(columns) == 2:
            time_data.append(float(columns[0]))
            voltage_data.append(float(columns[1]))

voltage_data = np.array(voltage_data) #converting voltage_data into a numpy array


# Create the plot
plt.figure(figsize=(10, 6))  # Optional: Set the figure size
plt.plot(time_data[0:100], voltage_data[0:100], color='b')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title('Adding a DC Shift Using 10uF Capacitor then Amplified')
plt.grid(True)


# Show the plot
plt.show()
