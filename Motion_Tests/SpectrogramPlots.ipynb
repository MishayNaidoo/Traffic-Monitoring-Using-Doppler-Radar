# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
from scipy.signal import stft
from scipy.signal import spectrogram
from scipy.io import wavfile

# %% [markdown]
# # PCM2900 AD8422 Hand Waving 1

# %%
# Plot the original spectrogram# Load the WAV file
filename = 'PCM2900_HandWave_1.wav'  # Replace with your WAV file's path
sample_rate, audio_data = wavfile.read(filename)

# Create a spectrogram
frequencies, times, Sxx = spectrogram(audio_data, fs=sample_rate, nperseg=4096, noverlap=512)
plt.figure(figsize=(12, 6))
plt.imshow(10 * np.log10(Sxx), aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 5000)
plt.colorbar(label='dB')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %%
# Convert the spectrogram to dB scale
Sxx_dB = 10 * np.log10(Sxx)

# Apply thresholding
threshold = 0  # dB
Sxx_dB[Sxx_dB < threshold] = -100

# Plot the thresholded spectrogram
plt.figure(figsize=(12, 6))
plt.imshow(Sxx_dB, aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Thresholded Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # PCM2900 AD8422 Walking Bad Version
# ## This gain and offset config on the amplifier board resulted in a much noisier output

# %%
# Plot the original spectrogram# Load the WAV file
filename = 'PCM2900_Walking_Bad.wav'  # Replace with your WAV file's path
sample_rate, audio_data = wavfile.read(filename)

# Create a spectrogram
frequencies, times, Sxx = spectrogram(audio_data, fs=sample_rate, nperseg=4096, noverlap=512)
plt.figure(figsize=(12, 6))
plt.imshow(10 * np.log10(Sxx), aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %%
# Convert the spectrogram to dB scale
Sxx_dB = 10 * np.log10(Sxx)

# Apply thresholding
threshold = 0  # dB
Sxx_dB[Sxx_dB < threshold] = -10

# Plot the thresholded spectrogram
plt.figure(figsize=(12, 6))
plt.imshow(Sxx_dB, aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 1000)
plt.colorbar(label='dB')
plt.title('Thresholded Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # ASUS Xonar AD 8422 Walking

# %%
# Plot the original spectrogram# Load the WAV file
filename = 'ASUSXonar_AD8422_Walking.wav'  # Replace with your WAV file's path
sample_rate, audio_data = wavfile.read(filename)

# Create a spectrogram
frequencies, times, Sxx = spectrogram(audio_data, fs=sample_rate, nperseg=4096, noverlap=512)
plt.figure(figsize=(12, 6))
plt.imshow(10 * np.log10(Sxx), aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %%
# Convert the spectrogram to dB scale
Sxx_dB = 10 * np.log10(Sxx)

# Apply thresholding
threshold = 0  # dB
Sxx_dB[Sxx_dB < threshold] = -40

# Plot the thresholded spectrogram
plt.figure(figsize=(12, 6))
plt.imshow(Sxx_dB, aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Thresholded Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # PCM2900 AD8422 DCSupply Walking

# %%
# Plot the original spectrogram# Load the WAV file
filename = 'PCM2900_AD8422_DCSupply_Walking.wav'  # Replace with your WAV file's path
sample_rate, audio_data = wavfile.read(filename)

# Create a spectrogram
frequencies, times, Sxx = spectrogram(audio_data, fs=sample_rate, nperseg=4096, noverlap=512)
plt.figure(figsize=(12, 6))
plt.imshow(10 * np.log10(Sxx), aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %%
# Convert the spectrogram to dB scale
Sxx_dB = 10 * np.log10(Sxx)

# Apply thresholding
threshold = 0  # dB
Sxx_dB[Sxx_dB < threshold] = -30

# Plot the thresholded spectrogram
plt.figure(figsize=(12, 6))
plt.imshow(Sxx_dB, aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Thresholded Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # PCM2900 AD8422 USB Power Walking

# %%
# Plot the original spectrogram# Load the WAV file
filename = 'PCM2900_AD8422_USBPower_Walking.wav'  # Replace with your WAV file's path
sample_rate, audio_data = wavfile.read(filename)

# Create a spectrogram
frequencies, times, Sxx = spectrogram(audio_data, fs=sample_rate, nperseg=4096, noverlap=512)
plt.figure(figsize=(12, 6))
plt.imshow(10 * np.log10(Sxx), aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()

# %%
# Convert the spectrogram to dB scale
Sxx_dB = 10 * np.log10(Sxx)

# Apply thresholding
threshold = 0  # dB
Sxx_dB[Sxx_dB < threshold] = -100

# Plot the thresholded spectrogram
plt.figure(figsize=(12, 6))
plt.imshow(Sxx_dB, aspect='auto', cmap='inferno', origin='lower',
           extent=[times.min(), times.max(), frequencies.min(), frequencies.max()])
plt.ylim(0, 10000)
plt.colorbar(label='dB')
plt.title('Thresholded Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.tight_layout()
plt.show()
