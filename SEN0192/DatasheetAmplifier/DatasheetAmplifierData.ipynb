# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import butter, lfilter

# %% [markdown]
# # Moving Hand Towards and Away from Radar in Close Proximity to Radar

# %%
# Read the data from the text file
with open('Some_Motion.txt', 'r') as file:
    data = file.read().strip().split(',')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)

data = data/1024 * 5
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Data Plot')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### FFT of this above signal

# %%
# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/15000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# Plot the original data and its FFT
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(N) * dt, data)
plt.title('Original Sampled Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Sampled Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 200)  # Display only positive frequencies
plt.ylim(0,10000)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Trying to remove noise using thresholding

# %%
data[data<3] = 0 #Using a threshold of 2.8V

# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/15000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# Plot the original data and its FFT
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(N) * dt, data)
plt.title('Original Sampled Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Sampled Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 200)  # Display only positive frequencies
plt.ylim(0,10000)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Moving Hand Towards and Away From Radar from 2m Away

# %%
# Read the data from the text file
with open('Hand_Motion_2m.txt', 'r') as file:
    data = file.read().strip().split(',')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)
data = data/1024 * 5
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Data Plot')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### FFT of Data

# %%
# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/15000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# Plot the original data and its FFT
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(N) * dt, data)
plt.title('Original Sampled Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Sampled Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 200)  # Display only positive frequencies
plt.ylim(0,10000)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Moving Hand at Various Speeds Up Close To Radar

# %%
# Read the data from the text file
with open('CloseHandMotionVariedSpeed.txt', 'r') as file:
    data = file.read().strip().split(',')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)
data = data/1024 * 5
data = data[63000:70000]
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Samples')
plt.ylabel('Voltage')
plt.title('HB100 Data Fed Through Datasheet Amplifier')
#plt.legend()
plt.grid(True)

plt.savefig('DatasheetAmplifier.png')
# Show the plot
plt.show()

# %% [markdown]
# ### FFT Of Data

# %%
# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/15000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# # Plot the original data and its FFT
# plt.figure(figsize=(10, 6))
# plt.subplot(2, 1, 1)
# plt.plot(np.arange(N) * dt, data)
# plt.title('Original Sampled Data')
# plt.xlabel('Time (s)')
# plt.ylabel('Amplitude')

# plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Amplified Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 1000)  # Display only positive frequencies
plt.ylim(0,10000)

plt.tight_layout()
plt.show()
