# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.signal import butter, lfilter

# %% [markdown]
# # Just Non-Inverting Amplifier Data

# %%
# Read the data from the text file
with open('HandMotion1m.txt', 'r') as file:
    data = file.read().strip().split('\n')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)
data = data/1024 * 5
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Hand Motion 1m Away From Radar')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Read the data from the text file
with open('HandMotionCloseUp.txt', 'r') as file:
    data = file.read().strip().split('\n')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)
data = data/4095 * 5
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Hand Motion 1m Away From Radar')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Read the data from the text file
with open('HandMotionWithNegativeRail.txt', 'r') as file:
    data = file.read().strip().split('\n')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)
data = data/4095 * 5
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Hand Motion 1m Away From Radar with Negative Rail on OpAmp')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Updated Non-Inverting OpAmp Design with DC Shift and Reduced Gain

# %%
# Read the data from the text file
with open('HandMotion1mV2.txt', 'r') as file:
    data = file.read().strip().split('\n')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)
data = data/4095 * 5
#data = data[2000:2500]
#data = data - 2.33
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Hand Motion 1m Away From Radar')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/2000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# Plot the original data and its FFT
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(N) * dt, data)
plt.title('Original Sampled Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Sampled Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 50)  # Display only positive frequencies
plt.ylim(0,1000)

plt.tight_layout()
plt.show()

# %%
# Read the data from the text file
with open('NoMotion.txt', 'r') as file:
    data = file.read().strip().split('\n')

# Convert the data to a NumPy array
data = np.array(data, dtype=int)
data = data/4095 * 5
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Voltage')
plt.title('No Motion')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Read the data from the text file
with open('TestingSamplingRateV3.txt', 'r') as file:
    data = file.read().strip().split('\n')
j = 0
for i in data:
    if i == '':
        data[j] = data[j-1]
    j = j+1
print(len(data))
# Convert the data to a NumPy array
data = np.array(data, dtype=int)

j = 0
for i in data:
    if i >= 10000 or i<=900:
        data[j] = data[j-1]
    j = j+1
data = data/4095 * 5
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Testing Sampling Rate V3')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# 124865

# %%
# Read the data from the text file
with open('PendulumTestV1.txt', 'r') as file:
    data = file.read().strip().split('\n')
j = 0
for i in data:
    if i == '':
        data[j] = data[j-1]
    j = j+1
#print(len(data))
# Convert the data to a NumPy array
data = np.array(data, dtype=int)

j = 0
for i in data:
    if i >= 10000 or i<=900:
        data[j] = data[j-1]
    j = j+1
data = data/4095 * 5
data = data - 2.3
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Pendulum Test V1')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/2000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# Plot the original data and its FFT
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(N) * dt, data)
plt.title('Original Sampled Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Sampled Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 1000)  # Display only positive frequencies
plt.ylim(0,1000)

plt.tight_layout()
plt.show()

# %%
# Read the data from the text file
with open('HandMotionUpCloseV2.txt', 'r') as file:
    data = file.read().strip().split('\n')
j = 0
for i in data:
    if i == '':
        data[j] = data[j-1]
    j = j+1
#print(len(data))
# Convert the data to a NumPy array
data = np.array(data, dtype=int)

j = 0
for i in data:
    if i >= 5000 or i<=900:
        data[j] = data[j-1]
    j = j+1
data = data/4095 * 5
data = data - 2.3
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Hand Motion Up Close V2')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/4000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# Plot the original data and its FFT
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(N) * dt, data)
plt.title('Original Sampled Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Sampled Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 1000)  # Display only positive frequencies
plt.ylim(0,1000)

plt.tight_layout()
plt.show()

# %%
# Read the data from the text file
with open('HandMotionUpCloseV3.txt', 'r') as file:
    data = file.read().strip().split('\n')
j = 0
for i in data:
    if i == '':
        data[j] = data[j-1]
    j = j+1
#print(len(data))
# Convert the data to a NumPy array
data = np.array(data, dtype=int)

j = 0
for i in data:
    if i >= 5000 or i<=1000:
        data[j] = data[j-1]
    j = j+1
data = data/4095 * 5
#data = data - 2.3
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Hand Motion Up Close V3')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Number of data points
N = len(data)

# Calculate the sample spacing (assuming uniform sampling)
dt = 1/4000  # Replace with the actual time spacing between samples if known

# Perform FFT
data_fft = np.fft.fft(data)
freqs = np.fft.fftfreq(N, dt)  # Frequency values corresponding to the FFT components

# Plot the original data and its FFT
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(np.arange(N) * dt, data)
plt.title('Original Sampled Data')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(freqs, np.abs(data_fft))
plt.title('FFT of Sampled Data')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim(0, 1000)  # Display only positive frequencies
plt.ylim(0,1000)

plt.tight_layout()
plt.show()

# %%
# Define the parameters for the spectrogram
window_size = 250  # Window size for the FFT
overlap    = 125  # Overlap between windows
Fs = 4000
# Window the signal
window = np.hanning(window_size)
windows = [data[i:i+window_size] * window for i in range(0, len(data)-window_size, window_size-overlap)]

# Compute the FFT for each window
spectrogram = [np.abs(np.fft.rfft(win))**2 for win in windows]

# Transpose the result to have time on the x-axis and frequency on the y-axis
spectrogram = np.array(spectrogram).T

# Plot the spectrogram
frequencies = np.fft.rfftfreq(window_size, d=1.0/Fs)
time = np.arange(len(spectrogram[0])) * (window_size - overlap) / Fs
plt.pcolormesh(time, frequencies, 10 * np.log10(spectrogram))
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.colorbar(label="Power spectral density (dB/Hz)")
plt.ylim([0, Fs/2.])
plt.show()

# %%
# Read the data from the text file
with open('HandMotionUpCloseV4.txt', 'r') as file:
    data = file.read().strip().split('\n')
j = 0
for i in data:
    if i == '':
        data[j] = data[j-1]
    j = j+1
#print(len(data))
# Convert the data to a NumPy array
data = np.array(data, dtype=int)

j = 0
for i in data:
    if i >= 5000 or i<=1000:
        data[j] = data[j-1]
    j = j+1
data = data/4095 * 5
#data = data - 2.3
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)


time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Hand Motion Up Close V4')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Define the parameters for the spectrogram
window_size = 256  # Window size for the FFT
overlap    = 128  # Overlap between windows
Fs = 4000
# Window the signal
window = np.hanning(window_size)
windows = [data[i:i+window_size] * window for i in range(0, len(data)-window_size, window_size-overlap)]

# Compute the FFT for each window
spectrogram = [np.abs(np.fft.rfft(win))**2 for win in windows]

# Transpose the result to have time on the x-axis and frequency on the y-axis
spectrogram = np.array(spectrogram).T

# Plot the spectrogram
frequencies = np.fft.rfftfreq(window_size, d=1.0/Fs)
time = np.arange(len(spectrogram[0])) * (window_size - overlap) / Fs
plt.pcolormesh(time, frequencies, 10 * np.log10(spectrogram))
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.colorbar(label="Power spectral density (dB/Hz)")
plt.ylim([0, Fs/2.])
plt.show()

# %%
# Read the data from the text file
with open('WalkingDataV1.txt', 'r') as file:
    data = file.read().strip().split('\n')
j = 0
for i in data:
    if i == '':
        data[j] = data[j-1]
    j = j+1
#print(len(data))
# Convert the data to a NumPy array
data = np.array(data, dtype=int)

j = 0
for i in data:
    if i >= 5000 or i<=1000:
        data[j] = data[j-1]
    j = j+1
data = data/4095 * 5
#data = data[120000:130000]
#data = data - 2.3
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)



        



time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Walking Data V1')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Testing Integration Gain

# %%
# Assuming your initial array has 100,000 values (you can replace this with your actual data)
data = data[0:220000]
initial_array = data

# Define segment lengths
total_values = len(initial_array)
segment_length_outer = 4000
segment_length_inner = 200



# Iterate over the initial array in segments of 4,000 values
for i in range(0, total_values, segment_length_outer):
    segment_outer = initial_array[i:i + segment_length_outer]
    
    # Initialize an array to store the element-wise sum of all 200-value subsegments
    sum_subsegments = np.zeros(segment_length_inner)
    
    # Iterate over the 4,000-value segment in segments of 200 values
    for j in range(0, segment_length_outer, segment_length_inner):
        segment_inner = segment_outer[j:j + segment_length_inner]
        
        # Element-wise add the 200-value subsegment to the sum_subsegments
        sum_subsegments += segment_inner
    
    # Store the sum of all 200-value subsegments in result_array
    result_array = np.append(result_array, sum_subsegments)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 27
#      24     sum_subsegments += segment_inner
#      26 # Store the sum of all 200-value subsegments in result_array
# ---> 27 result_array = np.append(result_array, sum_subsegments)
#
# NameError: name 'result_array' is not defined

# %%
# Read the data from the text file
with open('WalkingDataAt8m.txt', 'r') as file:
    data = file.read().strip().split('\n')
j = 0
for i in data:
    if i == '':
        data[j] = data[j-1]
    j = j+1
#print(len(data))
# Convert the data to a NumPy array
data = np.array(data, dtype=int)

j = 0
for i in data:
    if i >= 5000 or i<=1000:
        data[j] = data[j-1]
    j = j+1
data = data/4095 * 5
#data = data[120000:130000]
#data = data - 2.3
#data = data[2000:2500]
# Create a time array (assuming each data point corresponds to a time step)



        



time = np.arange(len(data))

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(time, data, label='Data')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Walking Data at 8m Away')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Sample rate and desired cutoff frequency
fs = 4000  # Sample rate in Hz
cutoff_frequency = 100  # Cutoff frequency in Hz

# Create a time vector (e.g., for 1 second of data)
t = np.linspace(0, 1, fs, endpoint=False)



# Design a low-pass Butterworth filter
order = 4  # Filter order
b, a = signal.butter(order, cutoff_frequency / (0.5 * fs), btype='low')

# Apply the filter to the data
filtered_data = signal.lfilter(b, a, data)

# Plot the original and filtered signals
plt.figure()
plt.plot(t, data, 'b-', label='Original Signal')
plt.plot(t, filtered_data, 'r-', linewidth=2, label='Filtered Signal')
plt.legend()
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Low-Pass Filtered Signal')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[140], line 19
#      17 # Plot the original and filtered signals
#      18 plt.figure()
# ---> 19 plt.plot(t, data, 'b-', label='Original Signal')
#      20 plt.plot(t, filtered_data, 'r-', linewidth=2, label='Filtered Signal')
#      21 plt.legend()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
# ...
