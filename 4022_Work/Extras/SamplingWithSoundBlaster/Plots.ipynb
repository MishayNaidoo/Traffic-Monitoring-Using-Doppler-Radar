# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# %% [markdown]
# # This notebook details me trying to sample and plot data using a soundcard

# %%
# Replace 'your_wav_file.wav' with the path to your WAV file
wav_file = 'TestingSaveFormat.wav'

# Read the WAV file
sample_rate, audio_data = wavfile.read(wav_file)

# Calculate the time values for the x-axis
time = np.arange(0, len(audio_data)) / sample_rate

# Plot the voltage-time graph
plt.figure(figsize=(10, 6))
plt.plot(time, audio_data, color='b')
plt.xlabel('Time (s)')
plt.ylabel('Voltage')
plt.title('Voltage-Time Plot')
plt.grid(True)
plt.show()
